# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L = np.pi

numx = 1025
xvec = np.linspace(-L, L, numx)

yvec = np.sin(xvec)

# %%
plt.plot(xvec, yvec)
plt.title('Sine Plot')
plt.suptitle('Test')
plt.xlabel('x')
plt.ylabel('Sin(x)')
plt.show()
